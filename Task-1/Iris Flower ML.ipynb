# %%
# Libraries used in this Machine Learning Project are pandas,numpy,matplotlib,klib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv(r'D:\Samarth\iris_train.csv')
df_test=pd.read_csv(r'D:\Samarth\iris_test.csv')

# %%
df_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_train.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.5          2.3           1.3          0.3
# 1             4.4          3.2           1.3          0.2
# 2             5.0          3.5           1.6          0.6
# 3             5.1          3.8           1.9          0.4
# 4             4.8          3.0           1.4          0.3
# ..            ...          ...           ...          ...
# 156           7.2          3.2           6.0          1.8
# 157           6.2          2.8           4.8          1.8
# 158           6.1          3.0           4.9          1.8
# 159           6.4          2.8           5.6          2.1
# 160           7.1          2.6           5.4          1.6
#
# [161 rows x 4 columns]

# %%
df_train.shape
# Out:
# (150, 5)

# %%
df_test.shape
# Out:
# (161, 4)

# %%
df_train.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df_test.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0           False        False         False        False
# 1           False        False         False        False
# 2           False        False         False        False
# 3           False        False         False        False
# 4           False        False         False        False
# ..            ...          ...           ...          ...
# 156         False        False         False        False
# 157         False        False         False        False
# 158         False        False         False        False
# 159         False        False         False        False
# 160         False        False         False        False
#
# [161 rows x 4 columns]

# %%
df_train.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  161 non-null    float64
#  1   sepal_width   161 non-null    float64
#  2   petal_length  161 non-null    float64
#  3   petal_width   161 non-null    float64
# dtypes: float64(4)
# memory usage: 5.2 KB

# %%
df_train.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_test.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    161.000000   161.000000    161.000000   161.000000
# mean       6.179503     2.900621      4.695652     1.552795
# std        0.715901     0.349195      1.099053     0.486834
# min        4.400000     2.000000      1.300000     0.200000
# 25%        5.600000     2.700000      4.200000     1.300000
# 50%        6.100000     2.900000      4.700000     1.500000
# 75%        6.700000     3.100000      5.600000     1.800000
# max        7.900000     3.800000      6.900000     2.500000

# %%
df_train.hist(figsize=(15,15))
plt.show()

# %%
from pandas_profiling import ProfileReport

# %%
profile=ProfileReport(df_train,title='Pandas Profiling Report')

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-11-18 09:22:25.384131&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_train.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_test.corr(),annot=True)
plt.show()

# %%
import klib

# %%
klib.corr_plot(df_train)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df_train)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %%
klib.dist_plot(df_test)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Density'>

# %%
klib.data_cleaning(df_train)
# Out:
# Shape of cleaned data: (147, 5)Remaining NAs: 0
#
# Changes:
# Dropped rows: 3
#      of which 3 duplicates. (Rows: [34, 37, 142])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.01 MB (-100.0%)
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.7          3.0           5.2          2.3  Iris-virginica
# 143           6.3          2.5           5.0          1.9  Iris-virginica
# ...

# %%
klib.data_cleaning(df_test)
# Out:
# Shape of cleaned data: (101, 4)Remaining NAs: 0
#
# Changes:
# Dropped rows: 60
#      of which 60 duplicates. (Rows: [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.01 MB (-100.0%)
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.5          2.3           1.3          0.3
# 1             4.4          3.2           1.3          0.2
# 2             5.0          3.5           1.6          0.6
# 3             5.1          3.8           1.9          0.4
# 4             4.8          3.0           1.4          0.3
# ..            ...          ...           ...          ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_train['species'] = le.fit_transform(df_train['species'])

# %%
df_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
X=df_train.drop('species',axis=1)

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
Y=df_train['species']

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=101, test_size=0.2)

# %%
X_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 104           6.5          3.0           5.8          2.2
# 89            5.5          2.5           4.0          1.3
# 116           6.5          3.0           5.5          1.8
# 82            5.8          2.7           3.9          1.2
# 112           6.8          3.0           5.5          2.1
# ..            ...          ...           ...          ...
# 63            6.1          2.9           4.7          1.4
# 70            5.9          3.2           4.8          1.8
# 81            5.5          2.4           3.7          1.0
# 11            4.8          3.4           1.6          0.2
# 95            5.7          3.0           4.2          1.2
#
# [120 rows x 4 columns]

# %%
Y_train
# Out:
# 104    2
# 89     1
# 116    2
# 82     1
# 112    2
#       ..
# 63     1
# 70     1
# 81     1
# 11     0
# 95     1
# Name: species, Length: 120, dtype: int32

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 33            5.5          4.2           1.4          0.2
# 16            5.4          3.9           1.3          0.4
# 43            5.0          3.5           1.6          0.6
# 129           7.2          3.0           5.8          1.6
# 50            7.0          3.2           4.7          1.4
# 123           6.3          2.7           4.9          1.8
# 68            6.2          2.2           4.5          1.5
# 53            5.5          2.3           4.0          1.3
# 146           6.3          2.5           5.0          1.9
# 1             4.9          3.0           1.4          0.2
# 147           6.5          3.0           5.2          2.0
# 32            5.2          4.1           1.5          0.1
# 31            5.4          3.4           1.5          0.4
# 122           7.7          2.8           6.7          2.0
# 127           6.1          3.0           4.9          1.8
# ...

# %%
Y_test
# Out:
# 33     0
# 16     0
# 43     0
# 129    2
# 50     1
# 123    2
# 68     1
# 53     1
# 146    2
# 1      0
# 147    2
# 32     0
# 31     0
# 122    2
# 127    2
# 74     1
# 88     1
# 96     1
# 42     0
# 134    2
# 80     1
# 48     0
# 90     1
# 65     1
# 97     1
# 64     1
# 93     1
# 114    2
# 25     0
# 41     0
# Name: species, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train_std = sc.fit_transform(X_train)

# %%
X_train_std
# Out:
# array([[ 0.76416119, -0.17706093,  1.11810042,  1.24773749],
#        [-0.42673937, -1.39817078,  0.10928801,  0.09892548],
#        [ 0.76416119, -0.17706093,  0.94996502,  0.73715437],
#        [-0.0694692 , -0.90972684,  0.05324288, -0.0287203 ],
#        [ 1.12143136, -0.17706093,  0.94996502,  1.12009171],
#        [-0.18855925, -0.66550487,  0.38951368,  0.09892548],
#        [ 1.0023413 ,  0.06716104,  0.50160395,  0.35421704],
#        [ 0.04962086, -0.17706093,  0.22137828,  0.35421704],
#        [-0.30764931, -0.90972684,  0.22137828,  0.09892548],
#        [ 2.19324186, -0.17706093,  1.28623582,  1.37538327],
#        [-0.90309959,  1.53249286, -1.29184033, -1.04988653],
#        [-1.49854987,  1.28827089, -1.572066  , -1.30517809],
#        [-1.37945981,  0.31138301, -1.2357952 , -1.30517809],
#        [ 1.0023413 , -0.17706093,  0.66973935,  0.6095086 ],
#        [-0.30764931, -0.17706093,  0.38951368,  0.35421704],
# ...

# %%
X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[-0.42673937,  2.75360271, -1.34788547, -1.30517809],
#        [-0.54582942,  2.0209368 , -1.4039306 , -1.04988653],
#        [-1.02218964,  1.04404892, -1.2357952 , -0.79459498],
#        [ 1.59779158, -0.17706093,  1.11810042,  0.48186282],
#        [ 1.35961147,  0.31138301,  0.50160395,  0.22657126],
#        [ 0.52598108, -0.90972684,  0.61369421,  0.73715437],
#        [ 0.40689102, -2.13083668,  0.38951368,  0.35421704],
#        [-0.42673937, -1.88661472,  0.10928801,  0.09892548],
#        [ 0.52598108, -1.39817078,  0.66973935,  0.86480015],
#        [-1.1412797 , -0.17706093, -1.34788547, -1.30517809],
#        [ 0.76416119, -0.17706093,  0.78182962,  0.99244593],
#        [-0.78400953,  2.50938074, -1.29184033, -1.43282387],
#        [-0.54582942,  0.79982695, -1.29184033, -1.04988653],
#        [ 2.19324186, -0.66550487,  1.62250662,  0.99244593],
#        [ 0.28780097, -0.17706093,  0.61369421,  0.73715437],
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_lr = lr.predict(X_test_std)

# %%
Y_pred_lr
# Out:
# array([-0.18652104, -0.01987784,  0.24229607,  1.50991054,  1.18720685,
#         1.60856726,  1.39425099,  1.21297918,  1.71733971, -0.01171032,
#         1.7507029 , -0.2093027 ,  0.06634351,  1.92176495,  1.59015607,
#         1.12939034,  1.14479607,  1.16424887, -0.01321305,  1.45948909,
#         1.02829775, -0.10157186,  1.17187449,  1.17266641,  1.14384262,
#         1.07712831,  0.92562167,  2.09202649,  0.01251244,  0.14929024])

# %%
Y_test
# Out:
# 33     0
# 16     0
# 43     0
# 129    2
# 50     1
# 123    2
# 68     1
# 53     1
# 146    2
# 1      0
# 147    2
# 32     0
# 31     0
# 122    2
# 127    2
# 74     1
# 88     1
# 96     1
# 42     0
# 134    2
# 80     1
# 48     0
# 90     1
# 65     1
# 97     1
# 64     1
# 93     1
# 114    2
# 25     0
# 41     0
# Name: species, dtype: int32

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print(r2_score(Y_test,Y_pred_lr))
print(mean_absolute_error(Y_test,Y_pred_lr))
print(np.sqrt(mean_squared_error(Y_test,Y_pred_lr)))
# Out:
# 0.911668248294988
# 0.18159317457396115
# 0.22936099376283178
